# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import numpy as np
from CaseDataPlotters import *

# %% [markdown]
# # Import data

# %%
# Example usage
end_date    =   pd.to_datetime('2022-09-01') 
start_date  =   pd.to_datetime('2022-05-5')
tmitig1     =   pd.to_datetime('2022-06-01') 
tmitig2     =   pd.to_datetime('2022-07-01') 
ts1         = 9 # Option to make discrete changes to serial interval
ts2         = 9
ts3         = 9
countries = []
# countries += ['Italy']
# countries += ['Germany']
# countries += ['The United Kingdom']
# countries += ['France']
# countries += ['Netherlands']
# countries += ['Spain']
# countries += ['Belgium']
countries += ['Sweden']
countries += ['Finland']
countries += ['Norway']
countries += ['Ireland']
#countries += ['Portugal']
countries += ['Denmark']
# countries += ['Switzerland']
# countries += ['Luxembourg']
# countries += ['The United States']
countries += ['Europe']

per_capita      = True  # Set to True for per capita, False for absolute values
smooth          = True
interpolation   = "quadratic"
window          = 7
legendsize      = 16
ts              = 9
labelsize       = 22
Maspalomas      = False
vaccine_dates   = False
ECDC_risk_assessment=False
special_country = "Europe"
special_color   = 'grey'
xticksize       = 18
yticksize       = 18
only_onset      = False
linewidth       = 4
PlotCumulativeCases(data,
                    countries, 
                    end_date, 
                    per_capita,
                    start_date=start_date,
                    special_country=special_country,
                    special_color=special_color,
                    smooth=smooth,
                    interpolation=interpolation,
                    legendsize=legendsize,
                    linewidth=linewidth,
                    xlabelsize=labelsize,
                    ylabelsize=labelsize,
                    yscale="linear",
                    only_onset=only_onset,
                    xticksize=xticksize,
                    yticksize = yticksize,
                    ymultiple = 20)
PlotWeeklyCases(data,countries, end_date, per_capita,start_date=start_date,special_country=special_country,special_color=special_color,ylim = None,title = "",smooth=smooth,interpolation=interpolation,legendsize=legendsize,linewidth=linewidth,labelsize=labelsize,xticksize=xticksize,yticksize=yticksize,only_onset=only_onset)
PlotGrowthRate(data,
               countries,
               end_date,
               per_capita,
               tmitig1=tmitig1,
               tmitig2=tmitig2,
               ts1=9,
               ts2=9,
               ts3=9,
               start_date=start_date,
               special_country=special_country,
               special_color=special_color,title = "",
               smooth=smooth,
               interpolation=interpolation,
               legendsize=0,
               ylim=(0,5),
               alpha = 0.8,
               linewidth=linewidth,
               labelsize=labelsize,
               xticksize=xticksize,
               yticksize=yticksize*1.2,
               only_onset=only_onset)
# Out:
# /Users/dhm160/Documents/GitHub/TANGO_model/PNAS_paper_data/Fig_S3/CaseDataPlotters.py:481: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax1.set_yticklabels(yticks,fontsize=yticksize)
